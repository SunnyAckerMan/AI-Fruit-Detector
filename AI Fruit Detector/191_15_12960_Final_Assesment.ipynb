# %% [markdown]
# ***Importing Libraries***

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ***Custome Model***

# %% [markdown]
# ***Scoreing and Testing of Prediction***

# %%
mobile = tf.keras.models.load_model('/content/drive/MyDrive/AI Lab/Final Assesment/keras_model.h5')
class_names = ['Orange','Banana','Papaya']

test_image_path = "/content/drive/MyDrive/AI Lab/Final Assesment/Banana1.jpg"
img = tf.keras.preprocessing.image.load_img(test_image_path, target_size = (224,224))

#Convert the Image into Array
img_arr = tf.keras.preprocessing.image.img_to_array(img)

#For deep learning we need 1 more dimension
final_img = np.expand_dims(img_arr, axis=0)

#Prediction, Scoreing, Printing
predictions = mobile.predict(final_img)
score = tf.nn.softmax(predictions[0])
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
